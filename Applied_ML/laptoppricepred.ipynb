# %% [markdown]
# ### Import libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load the dataset

# %%
import pandas as pd

df = pd.read_csv('laptop_data.csv')

# %% [markdown]
# ### Explore the dataset

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0       Inches          Price
# count  1303.00000  1303.000000    1303.000000
# mean    651.00000    15.017191   59870.042910
# std     376.28801     1.426304   37243.201786
# min       0.00000    10.100000    9270.720000
# 25%     325.50000    14.000000   31914.720000
# 50%     651.00000    15.600000   52054.560000
# 75%     976.50000    15.600000   79274.246400
# max    1302.00000    18.400000  324954.720000

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %% [markdown]
# ### Data preprocessing

# %% [markdown]
# #### Dropping unwanted columns

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
df.drop(columns= ['Unnamed: 0'],inplace = True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %% [markdown]
# #### Extracting numeric values from ram and weight columns

# %%
df['Ram'] = df['Ram'].str.replace('GB','')
df['Weight'] = df['Weight'].str.replace('kg','')

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232
# 2         Intel HD Graphics 620  No OS   1.86   30636.0000
# ...

# %%
df.dtypes
# Out:
# Company              object
# TypeName             object
# Inches              float64
# ScreenResolution     object
# Cpu                  object
# Ram                  object
# Memory               object
# Gpu                  object
# OpSys                object
# Weight               object
# Price               float64
# dtype: object

# %%
df['Ram'] = df['Ram'].astype('int64')
df['Weight'] = df['Weight'].astype('float64')

# %%
df.dtypes
# Out:
# Company              object
# TypeName             object
# Inches              float64
# ScreenResolution     object
# Cpu                  object
# Ram                   int64
# Memory               object
# Gpu                  object
# OpSys                object
# Weight              float64
# Price               float64
# dtype: object

# %% [markdown]
# #### Observing relationship between  (price and company) and (price and type)

# %%
df['Company'].value_counts()
# Out:
# Company
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Mediacom       7
# Razer          7
# Microsoft      6
# Vero           4
# Xiaomi         4
# Chuwi          3
# Fujitsu        3
# Google         3
# LG             3
# Huawei         2
# Name: count, dtype: int64

# %%
sns.barplot(x = df['Company'],y=df['Price'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
df['TypeName'].value_counts()
# Out:
# TypeName
# Notebook              727
# Gaming                205
# Ultrabook             196
# 2 in 1 Convertible    121
# Workstation            29
# Netbook                25
# Name: count, dtype: int64

# %%
sns.barplot(x = df['TypeName'],y=df['Price'])
plt.xticks(rotation = 'vertical')
plt.show()

# %% [markdown]
# #### Extracting features from the screenresolution column

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# IPS Panel 1366x768                                 7
# Touchscreen 2560x1440                              7
# 4K Ultra HD 3840x2160                              7
# IPS Panel Retina Display 2304x1440                 6
# IPS Panel Retina Display 2560x1600                 6
# Touchscreen 2256x1504                              6
# ...

# %%
df['Touchscreen'] = df['ScreenResolution'].apply(lambda x: 1 if 'Touchscreen' in x else 0)

# %%
df.sample(5)
# Out:
#     Company            TypeName  Inches                     ScreenResolution  \
# 216  Lenovo            Notebook    17.3                             1600x900
# 747      HP            Notebook    15.6                    Full HD 1920x1080
# 737    Dell  2 in 1 Convertible    13.3      Full HD / Touchscreen 1920x1080
# 911      HP           Ultrabook    12.5  4K Ultra HD / Touchscreen 3840x2160
# 384    Asus           Ultrabook    13.3      Full HD / Touchscreen 1920x1080
#
#                             Cpu  Ram     Memory                       Gpu  \
# 216  Intel Core i5 7200U 2.5GHz    8    1TB HDD  Nvidia GeForce GTX 940MX
# 747    Intel Core i3 6006U 2GHz    8  256GB SSD     Intel HD Graphics 520
# 737  Intel Core i5 8250U 1.6GHz    8    1TB HDD    Intel UHD Graphics 620
# 911    Intel Core M 6Y75 1.2GHz    8  240GB SSD     Intel HD Graphics 515
# 384  Intel Core i7 7500U 2.7GHz   16  512GB SSD     Intel HD Graphics 620
#
#           OpSys  Weight       Price  Touchscreen
# ...

# %%
df['Touchscreen'].value_counts()
# Out:
# Touchscreen
# 0    1111
# 1     192
# Name: count, dtype: int64

# %%
sns.barplot(x = df['Touchscreen'],y = df['Price'])
# Out:
# <Axes: xlabel='Touchscreen', ylabel='Price'>

# %%
df['IPS'] = df['ScreenResolution'].apply(lambda x: 1 if 'IPS' in x else 0)

# %%
df['IPS'].value_counts()
# Out:
# IPS
# 0    938
# 1    365
# Name: count, dtype: int64

# %%
sns.barplot(x = df['IPS'],y = df['Price'])
# Out:
# <Axes: xlabel='IPS', ylabel='Price'>

# %%
df.sample(5)
# Out:
#      Company            TypeName  Inches  \
# 1296      HP             Netbook    11.6
# 1290    Dell            Notebook    15.6
# 62    Lenovo            Notebook    14.0
# 867   Lenovo  2 in 1 Convertible    13.3
# 56        HP            Notebook    15.6
#
#                                ScreenResolution  \
# 1296                                   1366x768
# 1290                                   1366x768
# 62                  IPS Panel Full HD 1920x1080
# 867   IPS Panel Full HD / Touchscreen 1920x1080
# 56                            Full HD 1920x1080
#
#                                        Cpu  Ram              Memory  \
# 1296  Intel Celeron Dual Core N3060 1.6GHz    2  32GB Flash Storage
# 1290            Intel Core i3 7100U 2.4GHz    6             1TB HDD
# 62              Intel Core i3 7130U 2.7GHz    8           256GB SSD
# 867             Intel Core i7 7500U 2.7GHz    8           256GB SSD
# 56                Intel Core i3 6006U 2GHz    4           128GB SSD
#
# ...

# %%
resolution = df['ScreenResolution'].str.split('x',n = 1,expand = True)

# %%
df['X_res'] = resolution[0]
df['Y_res'] = resolution[1]
df.head(1)
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                     Cpu  Ram     Memory                           Gpu  OpSys  \
# 0  Intel Core i5 2.3GHz    8  128GB SSD  Intel Iris Plus Graphics 640  macOS
#
#    Weight       Price  Touchscreen  IPS                          X_res Y_res
# 0    1.37  71378.6832            0    1  IPS Panel Retina Display 2560  1600

# %%
df['X_res'] = df['X_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
df.head(1)
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                     Cpu  Ram     Memory                           Gpu  OpSys  \
# 0  Intel Core i5 2.3GHz    8  128GB SSD  Intel Iris Plus Graphics 640  macOS
#
#    Weight       Price  Touchscreen  IPS X_res Y_res
# 0    1.37  71378.6832            0    1  2560  1600

# %%
df.dtypes
# Out:
# Company              object
# TypeName             object
# Inches              float64
# ScreenResolution     object
# Cpu                  object
# Ram                   int64
# Memory               object
# Gpu                  object
# OpSys                object
# Weight              float64
# Price               float64
# Touchscreen           int64
# IPS                   int64
# X_res                object
# Y_res                object
# dtype: object

# %%
df['X_res'] = df['X_res'].astype('int64')
df['Y_res'] = df['Y_res'].astype('int64')

# %%
df.dtypes
# Out:
# Company              object
# TypeName             object
# Inches              float64
# ScreenResolution     object
# Cpu                  object
# Ram                   int64
# Memory               object
# Gpu                  object
# OpSys                object
# Weight              float64
# Price               float64
# Touchscreen           int64
# IPS                   int64
# X_res                 int64
# Y_res                 int64
# dtype: object

# %%
df.corr(numeric_only=True)['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# IPS            0.252208
# X_res          0.556529
# Y_res          0.552809
# Name: Price, dtype: float64

# %%
df['PPI'] = (((df['X_res']**2) + (df['Y_res']**2))**0.5/df['Inches']).astype('float64')

# %%
df.corr(numeric_only=True)['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# IPS            0.252208
# X_res          0.556529
# Y_res          0.552809
# PPI            0.473487
# Name: Price, dtype: float64

# %%
df.drop(columns= ['ScreenResolution'],inplace=True)

# %%
df.drop(columns=['Inches','X_res','Y_res'],inplace=True)

# %%
df.head(1)
# Out:
#   Company   TypeName                   Cpu  Ram     Memory  \
# 0   Apple  Ultrabook  Intel Core i5 2.3GHz    8  128GB SSD
#
#                             Gpu  OpSys  Weight       Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  71378.6832            0    1
#
#           PPI
# 0  226.983005

# %% [markdown]
# #### Extracting features from Cpu column

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core i5 7200U 2.70GHz        1
# Intel Core M M7-6Y75 1.2GHz        1
# Intel Core M 6Y54 1.1GHz           1
# AMD E-Series 9000 2.2GHz           1
# Samsung Cortex A72&A53 2.0GHz      1
# Name: count, Length: 118, dtype: int64

# %%
df['Cpu_name'] = df['Cpu'].apply(lambda x: " ".join(x.split()[0:3]))

# %%
df.sample(3)
# Out:
#      Company            TypeName                         Cpu  Ram     Memory  \
# 27      Dell            Notebook  Intel Core i5 8250U 1.6GHz    8  256GB SSD
# 1261    Asus           Ultrabook    Intel Core M 6Y30 0.9GHz    8  512GB SSD
# 674       HP  2 in 1 Convertible  Intel Core i3 7100U 2.4GHz    4  128GB SSD
#
#                         Gpu       OpSys  Weight     Price  Touchscreen  IPS  \
# 27           AMD Radeon 530  Windows 10    2.20  42624.00            0    0
# 1261  Intel HD Graphics 515  Windows 10    1.20  38841.12            0    1
# 674    Nvidia GeForce 940MX  Windows 10    1.63  37242.72            1    1
#
#              PPI       Cpu_name
# 27    141.211998  Intel Core i5
# 1261  165.632118   Intel Core M
# 674   157.350512  Intel Core i3

# %%
def fetch_processor(text):
  if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
    return text
  elif text.split()[0] == 'Intel':
    return 'Other Intel Processor'
  else:
    return 'AMD Processor'

# %%
df['Cpu_brand'] = df['Cpu_name'].apply(fetch_processor)

# %%
sns.barplot(x = df['Cpu_brand'],y = df['Price'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
df.drop(columns = ['Cpu','Cpu_name'],inplace = True)

# %%
df.head(1)
# Out:
#   Company   TypeName  Ram     Memory                           Gpu  OpSys  \
# 0   Apple  Ultrabook    8  128GB SSD  Intel Iris Plus Graphics 640  macOS
#
#    Weight       Price  Touchscreen  IPS         PPI      Cpu_brand
# 0    1.37  71378.6832            0    1  226.983005  Intel Core i5

# %% [markdown]
# #### Observing relation between Ram and Price column

# %%
sns.barplot(x = df['Ram'],y = df['Price'])
# Out:
# <Axes: xlabel='Ram', ylabel='Price'>

# %% [markdown]
# #### Extracting features from Memory column

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 1TB SSD                           14
# 512GB SSD +  1TB HDD              14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 16GB SSD                           3
# 512GB SSD +  2TB HDD               3
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  256GB SSD             2
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# ...

# %%
df['Memory'] = df['Memory'].astype(str)
df['Memory'] = df['Memory'].replace('\.0', '', regex=True)
df["Memory"] = df["Memory"].str.replace('GB', '')
df["Memory"] = df["Memory"].str.replace('TB', '000')
new = df["Memory"].str.split("+", n = 1, expand = True)

df["first"]= new[0]
df["first"]=df["first"].str.strip()

df["second"]= new[1]

df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['first'] = df['first'].str.replace(r'\D', '',regex = True)

df["second"].fillna("0", inplace = True)

df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['second'] = df['second'].str.replace(r'\D', '',regex=True)

df["first"] = df["first"].astype(int)
df["second"] = df["second"].astype(int)

df["HDD"]=(df["first"]*df["Layer1HDD"]+df["second"]*df["Layer2HDD"])
df["SSD"]=(df["first"]*df["Layer1SSD"]+df["second"]*df["Layer2SSD"])
df["Hybrid"]=(df["first"]*df["Layer1Hybrid"]+df["second"]*df["Layer2Hybrid"])
df["Flash_Storage"]=(df["first"]*df["Layer1Flash_Storage"]+df["second"]*df["Layer2Flash_Storage"])

df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash_Storage'],inplace=True)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\.'
# <>:2: SyntaxWarning: invalid escape sequence '\.'
# /tmp/ipykernel_231/4041832940.py:2: SyntaxWarning: invalid escape sequence '\.'
#   df['Memory'] = df['Memory'].replace('\.0', '', regex=True)
# /tmp/ipykernel_231/4041832940.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["second"].fillna("0", inplace = True)

# %%
df.sample(5)
# Out:
#     Company   TypeName  Ram   Memory                     Gpu       OpSys  \
# 52       HP   Notebook    4  256 SSD  AMD Radeon R4 Graphics  Windows 10
# 722  Lenovo  Ultrabook    8  256 SSD   Intel HD Graphics 620  Windows 10
# 614    Dell   Notebook    4  500 HDD   Intel HD Graphics 620       Linux
# 555    Asus   Notebook    4  500 HDD   Intel HD Graphics 500       Linux
# 865      HP   Notebook    4  500 HDD   Intel HD Graphics 520  Windows 10
#
#      Weight       Price  Touchscreen  IPS         PPI              Cpu_brand  \
# 52     1.86  21231.5472            0    0  141.211998          AMD Processor
# 722    1.32  79866.7200            0    1  157.350512          Intel Core i5
# 614    1.93  46300.3200            0    0  100.454670          Intel Core i5
# 555    2.00  11934.7200            0    0  100.454670  Other Intel Processor
# 865    2.07  48484.8000            0    0  141.211998          Intel Core i5
#
#      HDD  SSD  Hybrid  Flash_Storage
# ...

# %%
df.drop(columns=['Memory'],inplace=True)

# %%
df.corr(numeric_only=True)['Price']
# Out:
# Ram              0.743007
# Weight           0.210370
# Price            1.000000
# Touchscreen      0.191226
# IPS              0.252208
# PPI              0.473487
# HDD             -0.096441
# SSD              0.670799
# Hybrid           0.007989
# Flash_Storage   -0.040511
# Name: Price, dtype: float64

# %%
df.drop(columns=['Hybrid','Flash_Storage'],inplace=True)

# %%
df.head(1)
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
#
#         Price  Touchscreen  IPS         PPI      Cpu_brand  HDD  SSD
# 0  71378.6832            0    1  226.983005  Intel Core i5    0  128

# %% [markdown]
# #### Extracting features from Gpu column

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# Nvidia Quadro M500M          1
# AMD Radeon R7 M360           1
# Nvidia Quadro M3000M         1
# Nvidia GeForce 960M          1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
df['Gpu_brand'] = df['Gpu'].apply(lambda x:x.split()[0])

# %%
df.head(1)
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
#
#         Price  Touchscreen  IPS         PPI      Cpu_brand  HDD  SSD Gpu_brand
# 0  71378.6832            0    1  226.983005  Intel Core i5    0  128     Intel

# %%
df['Gpu_brand'].value_counts()
# Out:
# Gpu_brand
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
df = df[df['Gpu_brand'] != 'ARM']

# %%
df['Gpu_brand'].value_counts()
# Out:
# Gpu_brand
# Intel     722
# Nvidia    400
# AMD       180
# Name: count, dtype: int64

# %%
sns.barplot(x = df['Gpu_brand'],y = df['Price'])
# Out:
# <Axes: xlabel='Gpu_brand', ylabel='Price'>

# %%
df = df.drop(columns=['Gpu'])

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touchscreen  IPS  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0    1
#
#           PPI      Cpu_brand  HDD  SSD Gpu_brand
# 0  226.983005  Intel Core i5    0  128     Intel
# 1  127.677940  Intel Core i5    0    0     Intel
# 2  141.211998  Intel Core i5    0  256     Intel
# 3  220.534624  Intel Core i7    0  512       AMD
# 4  226.983005  Intel Core i5    0  256     Intel

# %% [markdown]
# #### Extracting feature from OpSys column

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
sns.barplot(x = df['OpSys'],y=df['Price'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
def fetch_os(text):
  if text == 'Windows 10' or text == 'Windows 7' or text == 'Windows 10 S':
    return 'Windows'
  elif text == 'macOS' or text == 'Mac OS X':
    return 'Mac'
  else:
    return 'Others/No OS/Linux'

# %%
df['Os'] = df['OpSys'].apply(fetch_os)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touchscreen  IPS  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0    1
#
#           PPI      Cpu_brand  HDD  SSD Gpu_brand                  Os
# 0  226.983005  Intel Core i5    0  128     Intel                 Mac
# 1  127.677940  Intel Core i5    0    0     Intel                 Mac
# 2  141.211998  Intel Core i5    0  256     Intel  Others/No OS/Linux
# 3  220.534624  Intel Core i7    0  512       AMD                 Mac
# 4  226.983005  Intel Core i5    0  256     Intel                 Mac

# %%
df.drop(columns=['OpSys'],inplace=True)

# %%
sns.barplot(x = df['Os'],y=df['Price'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %% [markdown]
# #### Log transformation on target variable

# %%
sns.displot(df['Price'])

# %%
sns.displot(np.log(df['Price']))

# %% [markdown]
# #### Handling categorical columns

# %%
df.dtypes
# Out:
# Company         object
# TypeName        object
# Ram              int64
# Weight         float64
# Price          float64
# Touchscreen      int64
# IPS              int64
# PPI            float64
# Cpu_brand       object
# HDD              int64
# SSD              int64
# Gpu_brand       object
# Os              object
# dtype: object

# %%
categorical_cols = df.select_dtypes('object').columns.tolist()
categorical_cols
# Out:
# ['Company', 'TypeName', 'Cpu_brand', 'Gpu_brand', 'Os']

# %%
df = pd.get_dummies(df,columns=categorical_cols,dtype=int,drop_first=True)

# %%
df.head()
# Out:
#    Ram  Weight        Price  Touchscreen  IPS         PPI  HDD  SSD  \
# 0    8    1.37   71378.6832            0    1  226.983005    0  128
# 1    8    1.34   47895.5232            0    0  127.677940    0    0
# 2    8    1.86   30636.0000            0    0  141.211998    0  256
# 3   16    1.83  135195.3360            0    1  220.534624    0  512
# 4    8    1.37   96095.8080            0    1  226.983005    0  256
#
#    Company_Apple  Company_Asus  ...  TypeName_Ultrabook  TypeName_Workstation  \
# 0              1             0  ...                   1                     0
# 1              1             0  ...                   1                     0
# 2              0             0  ...                   0                     0
# 3              1             0  ...                   1                     0
# 4              1             0  ...                   1                     0
#
#    Cpu_brand_Intel Core i3  Cpu_brand_Intel Core i5  Cpu_brand_Intel Core i7  \
# ...

# %% [markdown]
# #### Splitting the dataset

# %%
# df = df.sample(frac=1,random_state=42).reset_index(drop=True)
# split_index = int(0.8*len(df))

# train = df[:split_index]
# test = df[split_index:]

# %%
# print(train.shape)
# print(test.shape)
# nancount = train.isna().sum()
# print(nancount[nancount > 0])

# %%
# x_train = train.drop(columns='Price')
# y_train = np.log(train['Price'])
# x_test = test.drop(columns = 'Price')
# y_test = np.log(test['Price'])
# print(x_train['Company_Google'].isna().sum())
# print(x_test['Company_Google'].isna().sum())
# nancount = train.isna().sum()
# print(nancount[nancount > 0])
x = df.drop(columns = ['Price'])
y = np.log(df['Price'])
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test  = train_test_split(x,y,test_size = 0.2,shuffle = True,random_state = 42)

# %% [markdown]
# #### Scaling the data

# %%
# mean = x_train.mean()
# std = x_train.std()
# print(mean['Company_Google'])
# print(std['Company_Google'])

# %%
# x_train = (x_train - mean)/std
# x_test = (x_test - mean)/std
# nancount = x_train.isna().sum()
# print(nancount[nancount > 0])

# %% [markdown]
# ### Linear regression model

# %%
class Multiple_LR_Model:
    def __init__(self, learning_rate=0.01, iterations=1000):
        """
        Initialize the Linear Regression model.

        Args:
            learning_rate : Learning rate.Defaults to 0.01.
            iterations : Number of iteratoins for training.Defaults to 1000.
        """
        self.learning_rate = learning_rate
        self.interations = iterations
        self.w = None
        self.b = None

    def cost_function(self, x, y, w, b):
        """
        Compute the cost(squared error).

        Args:
            x (ndarray): Data, m examples with n features. Shape(m,n).
            y (ndarray): Target values. Shape(m,).
            w (ndarray): Model weights. Shape(n,).
            b (float): Model bias.

        Returns:
            cost (float): cost(sqaured error)
        """
        m = x.shape[0]
        cost = 0
        for i in range(m):
            fw_b = np.dot(x[i], w) + b
            cost += (fw_b - y[i]) ** 2
        total = cost / (2 * m)
        return total

    def compute_gradient(self, x, y, w, b):
        """
        Computes the gradient for linear regression.

        Args:
            x (ndarray): Data, m examples with n features. Shape(m,n).
            y (ndarray): Target values. Shape(m,).
            w (ndarray): Model weights. Shape(n,).
            b (float): Model bias.

        Returns:
            dj_dw : The gradient of the cost w.r.t. the weights. Shape(n,).
            dj_db : The gradient of the cost w.r.t. the bias.
        """
        m, n = x.shape
        dj_db = 0
        dj_dw = np.zeros((n,))
        for i in range(m):
            fw_b = np.dot(x[i], w) + b
            for j in range(n):
                dj_dw[j] += (fw_b - y[i]) * x[i, j]
            dj_db += fw_b - y[i]
        dj_dw = dj_dw / m
        dj_db = dj_db / m
        return dj_dw, dj_db

    def train_model(self, x, y):
        """
        Trains the model to the training data using gradient descent.

        Args:
            x (ndarray): Training data. Shape (m,n).
            y (ndarray): Traget values. Shape (m,).

        Returns:
            w (ndarray): Final wegihts calculated by gradient descent.
            b (float): Final bias calculated by gradient descent.
        """
        _, n = x.shape
        self.w = np.zeros(n)
        self.b = 0
        print(f"Initial cost :{self.cost_function(x, y, self.w, self.b):.4f}")
        for i in range(self.interations):
            dj_dw, dj_db = self.compute_gradient(x, y, self.w, self.b)
            self.w = self.w - self.learning_rate * dj_dw
            self.b = self.b - self.learning_rate * dj_db

        print(f"Final cost :{self.cost_function(x, y, self.w, self.b):.4f}")
        return self.w, self.b

    def predict(self, x):
        """
        Predicts target values for new input data.

        Args:
            x (ndarray): Input data. shape (m,n) or (n,).

        Returns:
            ndarray : Predicted value(s) using the linear regression model (np.dot(w,x) + b).

        """
        return np.dot(x, self.w) + self.b

# %%
# x_train_np = x_train.values
# y_train_np = y_train.values

# x_test_np = x_test.values
# y_test_np = y_test.values
# print(np.isnan(x_train_np).any())
# print(np.isinf(x_train_np).any())
# print(np.isnan(y_train_np).any())
# print(np.isinf(y_train_np).any())

# %%
# model = Multiple_LR_Model()
# model.train_model(x_train_np,y_train_np)

# %%
# result = model.predict(x_test_np)

# %%
# print(result.shape)
# print(y_test_np.shape)

# %%
# mae = np.mean(np.abs(y_test_np - result))
# print(f"MAE : {mae}")

# %% [markdown]
# ### Comparing different ML models

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.ensemble import BaggingRegressor,RandomForestRegressor

depth = int(np.log2(x_train.shape[0]))
print(depth)
#DecisionTreeRegressor model
model_decision_tree = DecisionTreeRegressor(max_depth = depth)
model_decision_tree.fit(x_train,y_train)

#LinearRegression model
# model1 = LinearRegression()
# model1.fit(x_train,y_train)

#BaggingRegressor model
# bagging = BaggingRegressor(estimator = DecisionTreeRegressor(),n_estimators = 100,max_samples = 600,bootstrap = True)
# bagging.fit(x_train,y_train)

#RandomForestRegressor
rforest = RandomForestRegressor(n_estimators = 500,max_depth=depth,criterion = "squared_error",bootstrap = True,max_samples = 700,min_samples_split=5)
rforest.fit(x_train,y_train)
# Out:
# 10
# RandomForestRegressor(max_depth=10, max_samples=700, min_samples_split=5,
#                       n_estimators=500)

# %%
# print(f"R2 for my custom Linear regression model on training data :{r2_score(model.predict(x_train_np),y_train_np)}")
# print(f"R2 score of sklearn Linear regression model on training data :{r2_score(model1.predict(x_train),y_train)}")
print(f"R2 score of sklearn Decision tree model on training data :{r2_score(model_decision_tree.predict(x_train),y_train)}")
# print(f"R2 score of sklearn BaggingRegressor model on training data :{r2_score(bagging.predict(x_train),y_train)}")
print(f"R2 score of sklearn RandomForestRegressor model on training data :{r2_score(rforest.predict(x_train),y_train)}")
# Out:
# R2 score of sklearn Decision tree model on training data :0.9453554315620927
# R2 score of sklearn RandomForestRegressor model on training data :0.9299091941487763

# %%
from sklearn.model_selection import KFold,cross_val_score

kf = KFold(n_splits = 5,shuffle = True,random_state = 42)

dt_scores = cross_val_score(model_decision_tree,x_train,y_train,cv = kf,scoring = 'r2')
rf_scores = cross_val_score(rforest,x_train,y_train,cv = kf,scoring = 'r2')

print(f"Decision Tree : {dt_scores} ")
print(f"Random Forest : {rf_scores}")
print(f"Decision Tree mean cross val score : {dt_scores.mean() } +- {dt_scores.std()}")
print(f"Random Forest mean cross val score : {rf_scores.mean()} +- {rf_scores.std()}")
# Out:
# Decision Tree : [0.71224732 0.78864813 0.77382386 0.78821794 0.82824993]
# Random Forest : [0.84398674 0.8478225  0.88098317 0.87000482 0.88467169]
# Decision Tree mean cross val score : 0.7782374369741702 +- 0.037638854588230235
# Random Forest mean cross val score : 0.8654937869008789 +- 0.016750461292967624

# %%
# print(f"R2 for my custom Linear regression model on test data :{r2_score(result,y_test_np)}")
# print(f"R2 score of sklearn Linear regression model on test data :{r2_score(model1.predict(x_test),y_test)}")
print(f"R2 score of sklearn Decision tree model on test data:{r2_score(model_decision_tree.predict(x_test),y_test)}")
# print(f"R2 score of sklearn BaggingRegressor model on test data :{r2_score(bagging.predict(x_test),y_test)}")
print(f"R2 score of sklearn RandomForestRegressor model on test data :{r2_score(rforest.predict(x_test),y_test)}")
# Out:
# R2 score of sklearn Decision tree model on test data:0.8007423641159599
# R2 score of sklearn RandomForestRegressor model on test data :0.8162091357064485

# %% [markdown]
# ### Grid Search for hyper parameter tuning

# %%
# from sklearn.model_selection import GridSearchCV

# rf = RandomForestRegressor(random_state = 42)

# param_grid = {
#     'n_estimators': [100,200,300,400],
#     'max_depth': [None,10,20],
#     'min_samples_split': [2,5,10],
#     'max_features': ['sqrt','log2'],
# }

# grid_search = GridSearchCV(estimator = rf,param_grid = param_grid,cv = 5,n_jobs = -1,scoring = 'r2')
# grid_search.fit(x_train,y_train)

# print(f"Best parameters : {grid_search.best_estimator_}")
# print(f"Best CV score : {grid_search.best_score_}")

# best_rf = grid_search.best_estimator_
# print(f"R2 score of best estimator found through Grid Search :{r2_score(best_rf.predict(x_test),y_test)}")

# %% [markdown]
# ### Boosting algorithms

# %%
from sklearn.ensemble import AdaBoostRegressor,GradientBoostingRegressor
from xgboost import XGBRegressor

#AdaBoost model
ada_boost = AdaBoostRegressor(n_estimators = 500,learning_rate = 0.1)
ada_boost.fit(x_train,y_train)

#GradientBoosting model
gradient_boost = GradientBoostingRegressor(n_estimators = 500,learning_rate = 0.1,max_depth = 8)
gradient_boost.fit(x_train,y_train)

#XGBoost model
xg = XGBRegressor(n_estimators = 500,learning_rate = 0.1,max_depth = 8,n_jobs = -1)
xg.fit(x_train,y_train)

#Cross validation scores
ada_scores = cross_val_score(ada_boost,x_train,y_train,cv = 5,scoring = 'r2')
gradient_scores = cross_val_score(gradient_boost,x_train,y_train,cv = 5,scoring = 'r2')
xg_scores = cross_val_score(xg,x_train,y_train,cv = 5,scoring = 'r2')

print(f"AdaBoost : {ada_scores} ")
print(f"GradientBoosting : {gradient_scores}")
print(f"XGBoostRegressor : {xg_scores}")

print("\n ********************************* \n")

print(f"AdaBoost mean cross val score : {ada_scores.mean() } +- {ada_scores.std()}")
print(f"GradientBoosting mean cross val score : {gradient_scores.mean()} +- {gradient_scores.std()}")
print(f"XGBoost mean cross val score : {xg_scores.mean()} +- {xg_scores.std()}")

print("\n ********************************* \n")

#R2 scores on unseen data
print(f"R2 score of AdaBoost : {r2_score(ada_boost.predict(x_test),y_test)}")
print(f"R2 score of Gradient Boosting : {r2_score(gradient_boost.predict(x_test),y_test)}")
print(f"R2 score of XGBoost : {r2_score(xg.predict(x_test),y_test)}")
# Out:
# AdaBoost : [0.83206904 0.80649345 0.82230618 0.8017985  0.73278407]
# GradientBoosting : [0.87295486 0.85757931 0.87908155 0.85580369 0.83619635]
# XGBoostRegressor : [0.87946656 0.87499212 0.89158293 0.84535781 0.84848436]
#
#  *********************************
#
# AdaBoost mean cross val score : 0.7990902465676062 +- 0.034886191390460515
# GradientBoosting mean cross val score : 0.8603231537949739 +- 0.01497661226660084
# XGBoost mean cross val score : 0.8679767565771679 +- 0.01805576135794138
#
#  *********************************
#
# R2 score of AdaBoost : 0.6351027917187964
# R2 score of Gradient Boosting : 0.8675465102893591
# R2 score of XGBoost : 0.8713291734970647
